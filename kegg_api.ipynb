# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishnavi132/testrepository/blob/main/kegg_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
import requests
from concurrent.futures import ThreadPoolExecutor, as_completed
import pandas as pd

"""loading the data and selecting the top 30 genes based on their expression level"""

#sorting and selecting only the genes which has the highest expression level
gene_ids_path = "/content/all_samples.fragments_per_gene.tsv"
gene_ids_df = pd.read_csv(gene_ids_path, sep='\t')

#adding all the expression data and then sorting the genes based on their total expression
gene_ids_df['Total_Expression'] = gene_ids_df.iloc[:, 1:].sum(axis=1)
top_genes = gene_ids_df.sort_values(by='Total_Expression', ascending=False).head(40)

top_genes[['feature', 'Total_Expression']]

# removing non-gene entries
non_gene_entries = ['__no_feature', '__alignment_not_unique', '__ambiguous']
filtered_genes = top_genes[~top_genes['feature'].isin(non_gene_entries)]

# printing the top 30 genes
actual_top_genes = filtered_genes.head(40)
actual_top_genes[['feature', 'Total_Expression']]

# Extracting only the Ensembl gene IDs from the final list
ensemble_ids = actual_top_genes['feature'].tolist()
ensemble_ids

# metabolite file
metabolite_ids_path = "/content/metabolites.tsv"
metabolite_ids_df = pd.read_csv(metabolite_ids_path, sep='\t')
metabolite_ids_list = metabolite_ids_df.iloc[:, 0].tolist()

# %%
"""conversion of ensemble ids to kegg ids via entrez ids """

#here we are converting the ensemble id to kegg id by converting it first to entrez id and then to the kegg id
#and then we make a results dataframe which will add all the ensemble ids in a dataframe

# using kegg api to convert the ensemble id to kegg id and then
# converting the entrez id to  kegg id
def get_entrez_id(ensembl_id):
    server = "https://rest.ensembl.org"
    ext = f"/xrefs/id/{ensembl_id}"
    headers = { "Content-Type" : "application/json"}
    r = requests.get(f"{server}{ext}", headers=headers)
    if not r.ok:
        r.raise_for_status()
        return None
    decoded = r.json()
    entrez_ids = [entry['primary_id'] for entry in decoded if entry['dbname'] == 'EntrezGene']
    return entrez_ids[0] if entrez_ids else None

def get_kegg_id_from_entrez(entrez_id):
    url = f"http://rest.kegg.jp/conv/genes/ncbi-geneid:{entrez_id}"
    response = requests.get(url)
    if response.ok and '\t' in response.text:
        kegg_id = response.text.split('\t')[1].strip()
        return kegg_id
    else:
        return None
def process_single_id(ensembl_id):
    try:
        entrez_id = get_entrez_id(ensembl_id)
        if entrez_id:
            kegg_id = get_kegg_id_from_entrez(entrez_id)
            if kegg_id:  # Checking if KEGG ID is found
                return ensembl_id, kegg_id
    except Exception as e:
        print(f"Error processing {ensembl_id}: {e}")
    return None, None

results = []
with ThreadPoolExecutor(max_workers=10) as executor:
    future_to_ensembl_id = {executor.submit(process_single_id, ensembl_id): ensembl_id for ensembl_id in ensemble_ids}

    for future in as_completed(future_to_ensembl_id):
        ensembl_id, kegg_id = future.result()
        if kegg_id:  # Append only if KEGG ID is found
            results.append({'Ensembl_ID': ensembl_id, 'KEGG_ID': kegg_id})
            #print(f'Processed {ensembl_id} to {kegg_id}')
            #print(kegg_id)
# Extracting KEGG IDs from the results list
kegg_id = [entry['KEGG_ID'] for entry in results]
results_df = pd.DataFrame(kegg_id)
print(results_df)
results_df.to_csv('/content/ensembl_to_kegg_ids.csv', index=False)
# Out:
#              0
# 0    mmu:17721
# 1    mmu:17711
# 2    mmu:17716
# 3    mmu:16483
# 4    mmu:14778
# 5    mmu:17719
# 6    mmu:17717
# 7    mmu:17708
# 8    mmu:14319
# 9    mmu:20505
# 10   mmu:13627
# 11  mmu:233799
# 12  mmu:230163
# 13   mmu:11928
# 14   mmu:14325
# 15  mmu:110213
# 16   mmu:26458
# 17   mmu:14775
# 18   mmu:11947
# 19   mmu:22242
# 20   mmu:11898
# 21   mmu:13629
# 22   mmu:13120
# 23   mmu:14433
# 24   mmu:11936
# 25   mmu:58810
# 26   mmu:66054
# 27   mmu:20363
# 28   mmu:71670
# 29   mmu:18263
# 30   mmu:11931
# 31   mmu:15481
# 32   mmu:21859
# 33   mmu:20521

# %%
"""Extracting the pathways associated with each gene kegg id """

def get_pathways_for_gene_kegg_id(kegg_gene_id):
    url = f"http://rest.kegg.jp/link/pathway/{kegg_gene_id}"
    response = requests.get(url)
    if response.ok:
        # Extracting the pathway IDs from the response
        pathway_ids = set()
        for line in response.text.strip().split('\n'):
            if '\t' in line:
                parts = line.split('\t')
                pathway_id = parts[1].strip()  # Extract the pathway ID
                pathway_ids.add(pathway_id)
        return pathway_ids
    else:
        print(f"Failed to get the pathways for the kegg ids {kegg_gene_id}")
        return set()

gene_pathways = {}

for gene_id in kegg_id:
    pathways = get_pathways_for_gene_kegg_id(gene_id)
    gene_pathways[gene_id] = pathways

for gene_id, pathways in gene_pathways.items():
    print(f"Gene {gene_id} : {pathways}")

# Convert the gene_pathways dictionary to a list of dictionaries for DataFrame conversion
data_for_df = [{'Gene_ID': gene_id, 'Pathways': ', '.join(pathways)} for gene_id, pathways in gene_pathways.items()]

# Create DataFrame
gene_pathways_df = pd.DataFrame(data_for_df)

# Display the DataFrame
print(gene_pathways_df)
# Out:
# Gene mmu:17721 : {'path:mmu01100', 'path:mmu04714', 'path:mmu05014', 'path:mmu05012', 'path:mmu00190', 'path:mmu04723', 'path:mmu05020', 'path:mmu05415', 'path:mmu05022', 'path:mmu05208', 'path:mmu05016', 'path:mmu05010'}
# Gene mmu:17711 : {'path:mmu01100', 'path:mmu04714', 'path:mmu05014', 'path:mmu05012', 'path:mmu00190', 'path:mmu05016', 'path:mmu04260', 'path:mmu05020', 'path:mmu05415', 'path:mmu05022', 'path:mmu05208', 'path:mmu04932', 'path:mmu05010'}
# Gene mmu:17716 : {'path:mmu01100', 'path:mmu04714', 'path:mmu05014', 'path:mmu05012', 'path:mmu00190', 'path:mmu04723', 'path:mmu05020', 'path:mmu05415', 'path:mmu05022', 'path:mmu05208', 'path:mmu05016', 'path:mmu05010'}
# Gene mmu:16483 : set()
# Gene mmu:14778 : {'path:mmu00480', 'path:mmu01100', 'path:mmu05014', 'path:mmu05022', 'path:mmu04918', 'path:mmu05016'}
# Gene mmu:17719 : {'path:mmu01100', 'path:mmu04714', 'path:mmu05014', 'path:mmu05012', 'path:mmu00190', 'path:mmu04723', 'path:mmu05020', 'path:mmu05415', 'path:mmu05022', 'path:mmu05208', 'path:mmu05016', 'path:mmu05010'}
# Gene mmu:17717 : {'path:mmu01100', 'path:mmu04714', 'path:mmu05014', 'path:mmu05012', 'path:mmu00190', 'path:mmu04723', 'path:mmu05020', 'path:mmu05415', 'path:mmu05022', 'path:mmu05208', 'path:mmu05016', 'path:mmu05010'}
# Gene mmu:17708 : {'path:mmu01100', 'path:mmu04714', 'path:mmu05014', 'path:mmu05012', 'path:mmu00190', 'path:mmu05016', 'path:mmu04260', 'path:mmu05020', 'path:mmu05415', 'path:mmu05022', 'path:mmu05208', 'path:mmu04932', 'path:mmu05010'}
# Gene mmu:14319 : {'path:mmu04978', 'path:mmu04216', 'path:mmu04217'}
# Gene mmu:20505 : {'path:mmu04978', 'path:mmu04928'}
# Gene mmu:13627 : {'path:mmu05134', 'path:mmu03013', 'path:mmu05140'}
# Gene mmu:233799 : {'path:mmu00650', 'path:mmu01100'}
# Gene mmu:230163 : {'path:mmu01100', 'path:mmu04066', 'path:mmu00010', 'path:mmu00030', 'path:mmu00051', 'path:mmu01230', 'path:mmu01200'}
# Gene mmu:11928 : {'path:mmu04970', 'path:mmu04978', 'path:mmu04974', 'path:mmu04973', 'path:mmu04919', 'path:mmu04911', 'path:mmu04971', 'path:mmu04976', 'path:mmu04260', 'path:mmu04960', 'path:mmu04261', 'path:mmu04024', 'path:mmu04961', 'path:mmu04972', 'path:mmu04918', 'path:mmu04925', 'path:mmu04964', 'path:mmu04022'}
# Gene mmu:14325 : {'path:mmu04978', 'path:mmu04216', 'path:mmu04217'}
# Gene mmu:110213 : set()
# Gene mmu:26458 : {'path:mmu04931', 'path:mmu03320', 'path:mmu04146'}
# Gene mmu:14775 : {'path:mmu00480', 'path:mmu01100', 'path:mmu05014', 'path:mmu05022', 'path:mmu04918', 'path:mmu05016'}
# Gene mmu:11947 : {'path:mmu01100', 'path:mmu04714', 'path:mmu05014', 'path:mmu05012', 'path:mmu00190', 'path:mmu05020', 'path:mmu05415', 'path:mmu05022', 'path:mmu05208', 'path:mmu05016', 'path:mmu05010'}
# Gene mmu:22242 : set()
# Gene mmu:11898 : {'path:mmu01100', 'path:mmu05418', 'path:mmu01230', 'path:mmu00250', 'path:mmu00220'}
# Gene mmu:13629 : {'path:mmu04921', 'path:mmu04152'}
# Gene mmu:13120 : set()
# Gene mmu:14433 : {'path:mmu05132', 'path:mmu01100', 'path:mmu04066', 'path:mmu00010', 'path:mmu05010', 'path:mmu05415', 'path:mmu01230', 'path:mmu01200'}
# Gene mmu:11936 : {'path:mmu04970', 'path:mmu04978', 'path:mmu04974', 'path:mmu04973', 'path:mmu04919', 'path:mmu04911', 'path:mmu04976', 'path:mmu04260', 'path:mmu04960', 'path:mmu04261', 'path:mmu04024', 'path:mmu04961', 'path:mmu04972', 'path:mmu04918', 'path:mmu04964', 'path:mmu04022'}
# Gene mmu:58810 : {'path:mmu01100', 'path:mmu00620', 'path:mmu00053', 'path:mmu00010', 'path:mmu00040', 'path:mmu01240', 'path:mmu05208', 'path:mmu00561'}
# Gene mmu:66054 : {'path:mmu00330', 'path:mmu01100', 'path:mmu00340', 'path:mmu00410'}
# Gene mmu:20363 : set()
# Gene mmu:71670 : set()
# Gene mmu:18263 : {'path:mmu00480', 'path:mmu00330', 'path:mmu01100', 'path:mmu04148'}
# Gene mmu:11931 : {'path:mmu04970', 'path:mmu04978', 'path:mmu04974', 'path:mmu04973', 'path:mmu04919', 'path:mmu04911', 'path:mmu04971', 'path:mmu04976', 'path:mmu04260', 'path:mmu04960', 'path:mmu04261', 'path:mmu04024', 'path:mmu04961', 'path:mmu04972', 'path:mmu04918', 'path:mmu04925', 'path:mmu04964', 'path:mmu04022'}
# Gene mmu:15481 : {'path:mmu04141', 'path:mmu04213', 'path:mmu05145', 'path:mmu05134', 'path:mmu05020', 'path:mmu04010', 'path:mmu05162', 'path:mmu04915', 'path:mmu04144', 'path:mmu05417', 'path:mmu04612', 'path:mmu03040'}
# Gene mmu:21859 : {'path:mmu05205', 'path:mmu05206'}
# Gene mmu:20521 : set()
#        Gene_ID                                           Pathways
# 0    mmu:17721  path:mmu01100, path:mmu04714, path:mmu05014, p...
# 1    mmu:17711  path:mmu01100, path:mmu04714, path:mmu05014, p...
# 2    mmu:17716  path:mmu01100, path:mmu04714, path:mmu05014, p...
# 3    mmu:16483
# 4    mmu:14778  path:mmu00480, path:mmu01100, path:mmu05014, p...
# 5    mmu:17719  path:mmu01100, path:mmu04714, path:mmu05014, p...
# 6    mmu:17717  path:mmu01100, path:mmu04714, path:mmu05014, p...
# 7    mmu:17708  path:mmu01100, path:mmu04714, path:mmu05014, p...
# 8    mmu:14319        path:mmu04978, path:mmu04216, path:mmu04217
# 9    mmu:20505                       path:mmu04978, path:mmu04928
# 10   mmu:13627        path:mmu05134, path:mmu03013, path:mmu05140
# 11  mmu:233799                       path:mmu00650, path:mmu01100
# 12  mmu:230163  path:mmu01100, path:mmu04066, path:mmu00010, p...
# 13   mmu:11928  path:mmu04970, path:mmu04978, path:mmu04974, p...
# 14   mmu:14325        path:mmu04978, path:mmu04216, path:mmu04217
# 15  mmu:110213
# 16   mmu:26458        path:mmu04931, path:mmu03320, path:mmu04146
# 17   mmu:14775  path:mmu00480, path:mmu01100, path:mmu05014, p...
# 18   mmu:11947  path:mmu01100, path:mmu04714, path:mmu05014, p...
# 19   mmu:22242
# 20   mmu:11898  path:mmu01100, path:mmu05418, path:mmu01230, p...
# 21   mmu:13629                       path:mmu04921, path:mmu04152
# 22   mmu:13120
# 23   mmu:14433  path:mmu05132, path:mmu01100, path:mmu04066, p...
# 24   mmu:11936  path:mmu04970, path:mmu04978, path:mmu04974, p...
# 25   mmu:58810  path:mmu01100, path:mmu00620, path:mmu00053, p...
# 26   mmu:66054  path:mmu00330, path:mmu01100, path:mmu00340, p...
# 27   mmu:20363
# 28   mmu:71670
# 29   mmu:18263  path:mmu00480, path:mmu00330, path:mmu01100, p...
# 30   mmu:11931  path:mmu04970, path:mmu04978, path:mmu04974, p...
# 31   mmu:15481  path:mmu04141, path:mmu04213, path:mmu05145, p...
# 32   mmu:21859                       path:mmu05205, path:mmu05206
# 33   mmu:20521

# %%
# creating a function get_metabolites_for_pathway to get metabolites for a given pathway
def get_metabolites_for_pathway(pathway_id):
    url = f"http://rest.kegg.jp/get/{pathway_id}"
    response = requests.get(url)
    metabolites = set()

    if response.ok:
        #here we are extracting the metabolites id which starts with C
        for line in response.text.split('\n'):
            if line.startswith("COMPOUND"):
                metabolite_ids = line.split()[1:]
                metabolites.update(metabolite_ids)
    else:
        print(f"Failed to retrieve metabolites for pathway {pathway_id}")

    return metabolites

gene_metabolites = {}

for gene_id, pathways in gene_pathways.items():
    all_metabolites = set()
    for pathway_id in pathways:
        metabolites = get_metabolites_for_pathway(pathway_id)
        all_metabolites.update(metabolites)
    gene_metabolites[gene_id] = all_metabolites

# Printing the results
for gene_id, metabolites in gene_metabolites.items():
    print(f"Gene {gene_id} is associated with metabolites: {metabolites}")
# Out:
# Gene mmu:17721 is associated with metabolites: {'H2O', 'ATP', 'peroxide', 'C00001', 'C00025', 'Hydrogen', 'L-Glutamate', 'C00027', 'C00002'}
# Gene mmu:17711 is associated with metabolites: {'H2O', 'ATP', 'peroxide', 'C00001', 'Calcium', 'D-Glucose', 'C00025', 'cation', 'Hydrogen', 'L-Glutamate', 'C00076', 'C00027', 'C00002', 'C00031'}
# Gene mmu:17716 is associated with metabolites: {'H2O', 'ATP', 'peroxide', 'C00001', 'C00025', 'Hydrogen', 'L-Glutamate', 'C00027', 'C00002'}
# Gene mmu:16483 is associated with metabolites: set()
# Gene mmu:14778 is associated with metabolites: {'H2O', 'NADPH', 'L-Glutamate', 'C00001', 'C00025', 'C00005'}
# Gene mmu:17719 is associated with metabolites: {'H2O', 'ATP', 'peroxide', 'C00001', 'C00025', 'Hydrogen', 'L-Glutamate', 'C00027', 'C00002'}
# Gene mmu:17717 is associated with metabolites: {'H2O', 'ATP', 'peroxide', 'C00001', 'C00025', 'Hydrogen', 'L-Glutamate', 'C00027', 'C00002'}
# Gene mmu:17708 is associated with metabolites: {'H2O', 'ATP', 'peroxide', 'C00001', 'Calcium', 'D-Glucose', 'C00025', 'cation', 'Hydrogen', 'L-Glutamate', 'C00076', 'C00027', 'C00002', 'C00031'}
# Gene mmu:14319 is associated with metabolites: {'Orthophosphate', 'ATP', 'C00010', 'C00002', 'CoA', 'C00009'}
# Gene mmu:20505 is associated with metabolites: {'Orthophosphate', 'C00009'}
# Gene mmu:13627 is associated with metabolites: {'C00338', 'Lipopolysaccharide', 'C00076', 'Calcium', 'cation'}
# Gene mmu:233799 is associated with metabolites: {'C00022', 'Pyruvate'}
# Gene mmu:230163 is associated with metabolites: {'C00022', 'ATP', 'D-Fructose', '6-phosphate', 'C00002', 'Pyruvate', 'C00085'}
# Gene mmu:11928 is associated with metabolites: {'H2O', 'ATP', 'CO2', 'C00020', 'C00001', 'Calcium', 'C00238', 'cation', 'C00009', 'NAD+', 'C00076', 'C00011', 'C00003', 'Potassium', 'AMP', 'Orthophosphate', 'C00002'}
# Gene mmu:14325 is associated with metabolites: {'Orthophosphate', 'ATP', 'C00010', 'C00002', 'CoA', 'C00009'}
# Gene mmu:110213 is associated with metabolites: set()
# Gene mmu:26458 is associated with metabolites: {'C00022', 'C02165', 'Leukotriene', 'B4', 'Pyruvate'}
# Gene mmu:14775 is associated with metabolites: {'H2O', 'NADPH', 'L-Glutamate', 'C00001', 'C00025', 'C00005'}
# Gene mmu:11947 is associated with metabolites: {'H2O', 'ATP', 'peroxide', 'C00001', 'C00025', 'Hydrogen', 'L-Glutamate', 'C00027', 'C00002'}
# Gene mmu:22242 is associated with metabolites: set()
# Gene mmu:11898 is associated with metabolites: {'C00076', 'CO2', 'C00011', 'C00014', 'Calcium', 'cation', 'Ammonia'}
# Gene mmu:13629 is associated with metabolites: {'NAD+', 'C00076', 'C00003', 'Calcium', 'cation'}
# Gene mmu:13120 is associated with metabolites: set()
# Gene mmu:14433 is associated with metabolites: {'C00022', 'H2O', 'ATP', 'peroxide', 'C00001', 'Pyruvate', 'C00338', 'Hydrogen', 'Lipopolysaccharide', 'C00027', 'C00002'}
# Gene mmu:11936 is associated with metabolites: {'H2O', 'ATP', 'CO2', 'C00020', 'C00001', 'Calcium', 'C00238', 'Potassium', 'cation', 'C00009', 'Orthophosphate', 'AMP', 'C00076', 'C00011', 'C00002'}
# Gene mmu:58810 is associated with metabolites: {'C00022', 'H2O', 'C00029', 'UDP-glucose', 'C00001', 'Pyruvate'}
# Gene mmu:66054 is associated with metabolites: {'Peptide', 'C00012', 'L-Glutamate', 'C00024', 'Acetyl-CoA', 'C00025'}
# Gene mmu:20363 is associated with metabolites: set()
# Gene mmu:71670 is associated with metabolites: set()
# Gene mmu:18263 is associated with metabolites: {'NADPH', 'ATP', 'C00012', 'Peptide', 'C00002', 'C00005'}
# Gene mmu:11931 is associated with metabolites: {'H2O', 'ATP', 'CO2', 'C00020', 'C00001', 'Calcium', 'C00238', 'cation', 'C00009', 'NAD+', 'C00076', 'C00011', 'C00003', 'Potassium', 'AMP', 'Orthophosphate', 'C00002'}
# Gene mmu:15481 is associated with metabolites: {'C05981', 'peroxide', 'C00035', 'Calcium', "3',5'-Cyclic", 'C00575', 'cation', 'AMP', 'C00338', 'Hydrogen', 'Phosphatidylinositol-3,4,5-trisphosphate', 'C00076', 'Lipopolysaccharide', 'GDP', 'C00027'}
# Gene mmu:21859 is associated with metabolites: {'C00426', 'Dermatan', 'sulfate'}
# Gene mmu:20521 is associated with metabolites: set()

# %%
# Function to integrate genes and metabolites for enriched pathways
def integrate_gene_metabolites_for_pathways(gene_pathways, gene_metabolites):
    pathway_integration = {}
    for gene_id, pathways in gene_pathways.items():
        for pathway in pathways:
            if pathway not in pathway_integration:
                pathway_integration[pathway] = {'genes': set(), 'metabolites': set()}
            pathway_integration[pathway]['genes'].add(gene_id)
            pathway_integration[pathway]['metabolites'].update(gene_metabolites[gene_id])
    return pathway_integration

# Integrating the data
integrated_data = integrate_gene_metabolites_for_pathways(gene_pathways, gene_metabolites)

# Displaying the integrated data
for pathway, data in integrated_data.items():
    print(f"Pathway {pathway} involves genes {data['genes']} and metabolites {data['metabolites']}")
# Out:
# Pathway path:mmu01100 involves genes {'mmu:18263', 'mmu:17711', 'mmu:17717', 'mmu:11898', 'mmu:17721', 'mmu:58810', 'mmu:17708', 'mmu:17719', 'mmu:66054', 'mmu:14433', 'mmu:230163', 'mmu:17716', 'mmu:14778', 'mmu:233799', 'mmu:11947', 'mmu:14775'} and metabolites {'H2O', 'ATP', 'C00012', 'CO2', 'Acetyl-CoA', 'C00014', 'C00025', 'C00029', 'C00076', 'Lipopolysaccharide', '6-phosphate', 'Peptide', 'peroxide', 'D-Glucose', 'Hydrogen', 'C00024', 'C00031', 'UDP-glucose', 'C00001', 'Calcium', 'Pyruvate', 'cation', 'Ammonia', 'NADPH', 'L-Glutamate', 'C00011', 'C00022', 'D-Fructose', 'C00085', 'C00005', 'C00338', 'C00027', 'C00002'}
# Pathway path:mmu04714 involves genes {'mmu:17711', 'mmu:17721', 'mmu:17708', 'mmu:17719', 'mmu:17716', 'mmu:17717', 'mmu:11947'} and metabolites {'H2O', 'ATP', 'C00001', 'Calcium', 'C00025', 'cation', 'L-Glutamate', 'C00076', 'peroxide', 'D-Glucose', 'Hydrogen', 'C00027', 'C00002', 'C00031'}
# Pathway path:mmu05014 involves genes {'mmu:17711', 'mmu:17717', 'mmu:17721', 'mmu:17708', 'mmu:17719', 'mmu:17716', 'mmu:14778', 'mmu:14775', 'mmu:11947'} and metabolites {'H2O', 'ATP', 'C00001', 'Calcium', 'C00025', 'cation', 'NADPH', 'L-Glutamate', 'C00076', 'peroxide', 'D-Glucose', 'C00005', 'Hydrogen', 'C00027', 'C00002', 'C00031'}
# Pathway path:mmu05012 involves genes {'mmu:17711', 'mmu:17721', 'mmu:17708', 'mmu:17719', 'mmu:17716', 'mmu:17717', 'mmu:11947'} and metabolites {'H2O', 'ATP', 'C00001', 'Calcium', 'C00025', 'cation', 'L-Glutamate', 'C00076', 'peroxide', 'D-Glucose', 'Hydrogen', 'C00027', 'C00002', 'C00031'}
# Pathway path:mmu00190 involves genes {'mmu:17711', 'mmu:17721', 'mmu:17708', 'mmu:17719', 'mmu:17716', 'mmu:17717', 'mmu:11947'} and metabolites {'H2O', 'ATP', 'C00001', 'Calcium', 'C00025', 'cation', 'L-Glutamate', 'C00076', 'peroxide', 'D-Glucose', 'Hydrogen', 'C00027', 'C00002', 'C00031'}
# Pathway path:mmu04723 involves genes {'mmu:17719', 'mmu:17717', 'mmu:17716', 'mmu:17721'} and metabolites {'H2O', 'ATP', 'peroxide', 'C00001', 'C00025', 'Hydrogen', 'L-Glutamate', 'C00027', 'C00002'}
# Pathway path:mmu05020 involves genes {'mmu:17711', 'mmu:15481', 'mmu:17721', 'mmu:17708', 'mmu:17719', 'mmu:17716', 'mmu:17717', 'mmu:11947'} and metabolites {'H2O', 'C05981', 'ATP', 'C00001', 'Calcium', 'C00025', 'cation', "3',5'-Cyclic", 'C00575', 'L-Glutamate', 'Phosphatidylinositol-3,4,5-trisphosphate', 'C00076', 'Lipopolysaccharide', 'GDP', 'peroxide', 'C00035', 'D-Glucose', 'AMP', 'Hydrogen', 'C00338', 'C00027', 'C00002', 'C00031'}
# Pathway path:mmu05415 involves genes {'mmu:17711', 'mmu:17721', 'mmu:17708', 'mmu:17719', 'mmu:14433', 'mmu:17716', 'mmu:17717', 'mmu:11947'} and metabolites {'H2O', 'ATP', 'C00001', 'Calcium', 'Pyruvate', 'C00025', 'cation', 'L-Glutamate', 'C00076', 'Lipopolysaccharide', 'C00022', 'peroxide', 'D-Glucose', 'Hydrogen', 'C00338', 'C00027', 'C00002', 'C00031'}
# Pathway path:mmu05022 involves genes {'mmu:17711', 'mmu:17717', 'mmu:17721', 'mmu:17708', 'mmu:17719', 'mmu:17716', 'mmu:14778', 'mmu:14775', 'mmu:11947'} and metabolites {'H2O', 'ATP', 'C00001', 'Calcium', 'C00025', 'cation', 'NADPH', 'L-Glutamate', 'C00076', 'peroxide', 'D-Glucose', 'C00005', 'Hydrogen', 'C00027', 'C00002', 'C00031'}
# Pathway path:mmu05208 involves genes {'mmu:17711', 'mmu:17721', 'mmu:58810', 'mmu:17708', 'mmu:17719', 'mmu:17716', 'mmu:17717', 'mmu:11947'} and metabolites {'H2O', 'ATP', 'UDP-glucose', 'C00001', 'Calcium', 'Pyruvate', 'C00025', 'cation', 'C00029', 'L-Glutamate', 'C00076', 'C00022', 'peroxide', 'D-Glucose', 'Hydrogen', 'C00027', 'C00002', 'C00031'}
# Pathway path:mmu05016 involves genes {'mmu:17711', 'mmu:17717', 'mmu:17721', 'mmu:17708', 'mmu:17719', 'mmu:17716', 'mmu:14778', 'mmu:14775', 'mmu:11947'} and metabolites {'H2O', 'ATP', 'C00001', 'Calcium', 'C00025', 'cation', 'NADPH', 'L-Glutamate', 'C00076', 'peroxide', 'D-Glucose', 'C00005', 'Hydrogen', 'C00027', 'C00002', 'C00031'}
# Pathway path:mmu05010 involves genes {'mmu:17711', 'mmu:17721', 'mmu:17708', 'mmu:17719', 'mmu:14433', 'mmu:17716', 'mmu:17717', 'mmu:11947'} and metabolites {'H2O', 'ATP', 'C00001', 'Calcium', 'Pyruvate', 'C00025', 'cation', 'L-Glutamate', 'C00076', 'Lipopolysaccharide', 'C00022', 'peroxide', 'D-Glucose', 'Hydrogen', 'C00338', 'C00027', 'C00002', 'C00031'}
# Pathway path:mmu04260 involves genes {'mmu:17711', 'mmu:11936', 'mmu:11931', 'mmu:17708', 'mmu:11928'} and metabolites {'H2O', 'ATP', 'CO2', 'C00238', 'C00025', 'C00009', 'NAD+', 'C00076', 'peroxide', 'C00003', 'D-Glucose', 'Potassium', 'Hydrogen', 'Orthophosphate', 'C00031', 'C00020', 'C00001', 'Calcium', 'cation', 'L-Glutamate', 'C00011', 'AMP', 'C00027', 'C00002'}
# Pathway path:mmu04932 involves genes {'mmu:17711', 'mmu:17708'} and metabolites {'H2O', 'ATP', 'C00001', 'Calcium', 'C00025', 'cation', 'L-Glutamate', 'C00076', 'peroxide', 'D-Glucose', 'Hydrogen', 'C00027', 'C00002', 'C00031'}
# Pathway path:mmu00480 involves genes {'mmu:14778', 'mmu:14775', 'mmu:18263'} and metabolites {'H2O', 'ATP', 'C00012', 'Peptide', 'C00001', 'C00025', 'C00005', 'NADPH', 'L-Glutamate', 'C00002'}
# Pathway path:mmu04918 involves genes {'mmu:11936', 'mmu:11931', 'mmu:11928', 'mmu:14778', 'mmu:14775'} and metabolites {'H2O', 'ATP', 'CO2', 'C00238', 'C00025', 'C00009', 'NAD+', 'C00076', 'C00003', 'Potassium', 'Orthophosphate', 'C00020', 'C00001', 'Calcium', 'cation', 'NADPH', 'L-Glutamate', 'C00011', 'C00005', 'AMP', 'C00002'}
# Pathway path:mmu04978 involves genes {'mmu:11936', 'mmu:11931', 'mmu:11928', 'mmu:14325', 'mmu:20505', 'mmu:14319'} and metabolites {'H2O', 'ATP', 'CO2', 'C00020', 'C00001', 'Calcium', 'C00238', 'cation', 'C00009', 'NAD+', 'C00010', 'C00076', 'C00011', 'C00003', 'Potassium', 'AMP', 'Orthophosphate', 'C00002', 'CoA'}
# Pathway path:mmu04216 involves genes {'mmu:14325', 'mmu:14319'} and metabolites {'ATP', 'C00009', 'Orthophosphate', 'C00010', 'C00002', 'CoA'}
# Pathway path:mmu04217 involves genes {'mmu:14325', 'mmu:14319'} and metabolites {'ATP', 'C00009', 'Orthophosphate', 'C00010', 'C00002', 'CoA'}
# Pathway path:mmu04928 involves genes {'mmu:20505'} and metabolites {'Orthophosphate', 'C00009'}
# Pathway path:mmu05134 involves genes {'mmu:13627', 'mmu:15481'} and metabolites {'C05981', 'Calcium', "3',5'-Cyclic", 'cation', 'C00575', 'Phosphatidylinositol-3,4,5-trisphosphate', 'Lipopolysaccharide', 'C00076', 'GDP', 'peroxide', 'C00035', 'AMP', 'C00338', 'Hydrogen', 'C00027'}
# Pathway path:mmu03013 involves genes {'mmu:13627'} and metabolites {'C00338', 'Lipopolysaccharide', 'C00076', 'Calcium', 'cation'}
# Pathway path:mmu05140 involves genes {'mmu:13627'} and metabolites {'C00338', 'Lipopolysaccharide', 'C00076', 'Calcium', 'cation'}
# Pathway path:mmu00650 involves genes {'mmu:233799'} and metabolites {'C00022', 'Pyruvate'}
# Pathway path:mmu04066 involves genes {'mmu:14433', 'mmu:230163'} and metabolites {'H2O', 'ATP', 'C00001', 'Pyruvate', 'Lipopolysaccharide', '6-phosphate', 'C00022', 'D-Fructose', 'peroxide', 'C00085', 'C00338', 'Hydrogen', 'C00027', 'C00002'}
# Pathway path:mmu00010 involves genes {'mmu:58810', 'mmu:14433', 'mmu:230163'} and metabolites {'H2O', 'ATP', 'UDP-glucose', 'C00001', 'Pyruvate', 'C00029', 'Lipopolysaccharide', '6-phosphate', 'C00022', 'D-Fructose', 'peroxide', 'C00085', 'C00338', 'Hydrogen', 'C00027', 'C00002'}
# Pathway path:mmu00030 involves genes {'mmu:230163'} and metabolites {'C00022', 'ATP', 'D-Fructose', '6-phosphate', 'C00002', 'Pyruvate', 'C00085'}
# Pathway path:mmu00051 involves genes {'mmu:230163'} and metabolites {'C00022', 'ATP', 'D-Fructose', '6-phosphate', 'C00002', 'Pyruvate', 'C00085'}
# Pathway path:mmu01230 involves genes {'mmu:14433', 'mmu:230163', 'mmu:11898'} and metabolites {'H2O', 'ATP', 'CO2', 'C00014', 'C00001', 'Calcium', 'Pyruvate', 'cation', 'Ammonia', 'C00076', 'Lipopolysaccharide', 'C00011', '6-phosphate', 'C00022', 'D-Fructose', 'peroxide', 'C00085', 'C00338', 'Hydrogen', 'C00027', 'C00002'}
# Pathway path:mmu01200 involves genes {'mmu:14433', 'mmu:230163'} and metabolites {'H2O', 'ATP', 'C00001', 'Pyruvate', 'Lipopolysaccharide', '6-phosphate', 'C00022', 'D-Fructose', 'peroxide', 'C00085', 'C00338', 'Hydrogen', 'C00027', 'C00002'}
# Pathway path:mmu04970 involves genes {'mmu:11936', 'mmu:11931', 'mmu:11928'} and metabolites {'H2O', 'ATP', 'CO2', 'C00020', 'C00001', 'Calcium', 'C00238', 'cation', 'C00009', 'NAD+', 'C00076', 'C00011', 'C00003', 'Potassium', 'AMP', 'Orthophosphate', 'C00002'}
# Pathway path:mmu04974 involves genes {'mmu:11936', 'mmu:11931', 'mmu:11928'} and metabolites {'H2O', 'ATP', 'CO2', 'C00020', 'C00001', 'Calcium', 'C00238', 'cation', 'C00009', 'NAD+', 'C00076', 'C00011', 'C00003', 'Potassium', 'AMP', 'Orthophosphate', 'C00002'}
# Pathway path:mmu04973 involves genes {'mmu:11936', 'mmu:11931', 'mmu:11928'} and metabolites {'H2O', 'ATP', 'CO2', 'C00020', 'C00001', 'Calcium', 'C00238', 'cation', 'C00009', 'NAD+', 'C00076', 'C00011', 'C00003', 'Potassium', 'AMP', 'Orthophosphate', 'C00002'}
# Pathway path:mmu04919 involves genes {'mmu:11936', 'mmu:11931', 'mmu:11928'} and metabolites {'H2O', 'ATP', 'CO2', 'C00020', 'C00001', 'Calcium', 'C00238', 'cation', 'C00009', 'NAD+', 'C00076', 'C00011', 'C00003', 'Potassium', 'AMP', 'Orthophosphate', 'C00002'}
# Pathway path:mmu04911 involves genes {'mmu:11936', 'mmu:11931', 'mmu:11928'} and metabolites {'H2O', 'ATP', 'CO2', 'C00020', 'C00001', 'Calcium', 'C00238', 'cation', 'C00009', 'NAD+', 'C00076', 'C00011', 'C00003', 'Potassium', 'AMP', 'Orthophosphate', 'C00002'}
# Pathway path:mmu04971 involves genes {'mmu:11931', 'mmu:11928'} and metabolites {'H2O', 'ATP', 'CO2', 'C00020', 'C00001', 'Calcium', 'C00238', 'cation', 'C00009', 'NAD+', 'C00076', 'C00011', 'C00003', 'Potassium', 'AMP', 'Orthophosphate', 'C00002'}
# Pathway path:mmu04976 involves genes {'mmu:11936', 'mmu:11931', 'mmu:11928'} and metabolites {'H2O', 'ATP', 'CO2', 'C00020', 'C00001', 'Calcium', 'C00238', 'cation', 'C00009', 'NAD+', 'C00076', 'C00011', 'C00003', 'Potassium', 'AMP', 'Orthophosphate', 'C00002'}
# Pathway path:mmu04960 involves genes {'mmu:11936', 'mmu:11931', 'mmu:11928'} and metabolites {'H2O', 'ATP', 'CO2', 'C00020', 'C00001', 'Calcium', 'C00238', 'cation', 'C00009', 'NAD+', 'C00076', 'C00011', 'C00003', 'Potassium', 'AMP', 'Orthophosphate', 'C00002'}
# Pathway path:mmu04261 involves genes {'mmu:11936', 'mmu:11931', 'mmu:11928'} and metabolites {'H2O', 'ATP', 'CO2', 'C00020', 'C00001', 'Calcium', 'C00238', 'cation', 'C00009', 'NAD+', 'C00076', 'C00011', 'C00003', 'Potassium', 'AMP', 'Orthophosphate', 'C00002'}
# Pathway path:mmu04024 involves genes {'mmu:11936', 'mmu:11931', 'mmu:11928'} and metabolites {'H2O', 'ATP', 'CO2', 'C00020', 'C00001', 'Calcium', 'C00238', 'cation', 'C00009', 'NAD+', 'C00076', 'C00011', 'C00003', 'Potassium', 'AMP', 'Orthophosphate', 'C00002'}
# Pathway path:mmu04961 involves genes {'mmu:11936', 'mmu:11931', 'mmu:11928'} and metabolites {'H2O', 'ATP', 'CO2', 'C00020', 'C00001', 'Calcium', 'C00238', 'cation', 'C00009', 'NAD+', 'C00076', 'C00011', 'C00003', 'Potassium', 'AMP', 'Orthophosphate', 'C00002'}
# Pathway path:mmu04972 involves genes {'mmu:11936', 'mmu:11931', 'mmu:11928'} and metabolites {'H2O', 'ATP', 'CO2', 'C00020', 'C00001', 'Calcium', 'C00238', 'cation', 'C00009', 'NAD+', 'C00076', 'C00011', 'C00003', 'Potassium', 'AMP', 'Orthophosphate', 'C00002'}
# Pathway path:mmu04925 involves genes {'mmu:11931', 'mmu:11928'} and metabolites {'H2O', 'ATP', 'CO2', 'C00020', 'C00001', 'Calcium', 'C00238', 'cation', 'C00009', 'NAD+', 'C00076', 'C00011', 'C00003', 'Potassium', 'AMP', 'Orthophosphate', 'C00002'}
# Pathway path:mmu04964 involves genes {'mmu:11936', 'mmu:11931', 'mmu:11928'} and metabolites {'H2O', 'ATP', 'CO2', 'C00020', 'C00001', 'Calcium', 'C00238', 'cation', 'C00009', 'NAD+', 'C00076', 'C00011', 'C00003', 'Potassium', 'AMP', 'Orthophosphate', 'C00002'}
# Pathway path:mmu04022 involves genes {'mmu:11936', 'mmu:11931', 'mmu:11928'} and metabolites {'H2O', 'ATP', 'CO2', 'C00020', 'C00001', 'Calcium', 'C00238', 'cation', 'C00009', 'NAD+', 'C00076', 'C00011', 'C00003', 'Potassium', 'AMP', 'Orthophosphate', 'C00002'}
# Pathway path:mmu04931 involves genes {'mmu:26458'} and metabolites {'C00022', 'C02165', 'Leukotriene', 'B4', 'Pyruvate'}
# Pathway path:mmu03320 involves genes {'mmu:26458'} and metabolites {'C00022', 'C02165', 'Leukotriene', 'B4', 'Pyruvate'}
# Pathway path:mmu04146 involves genes {'mmu:26458'} and metabolites {'C00022', 'C02165', 'Leukotriene', 'B4', 'Pyruvate'}
# Pathway path:mmu05418 involves genes {'mmu:11898'} and metabolites {'C00076', 'CO2', 'C00011', 'C00014', 'Calcium', 'cation', 'Ammonia'}
# Pathway path:mmu00250 involves genes {'mmu:11898'} and metabolites {'C00076', 'CO2', 'C00011', 'C00014', 'Calcium', 'cation', 'Ammonia'}
# Pathway path:mmu00220 involves genes {'mmu:11898'} and metabolites {'C00076', 'CO2', 'C00011', 'C00014', 'Calcium', 'cation', 'Ammonia'}
# Pathway path:mmu04921 involves genes {'mmu:13629'} and metabolites {'NAD+', 'C00076', 'C00003', 'Calcium', 'cation'}
# Pathway path:mmu04152 involves genes {'mmu:13629'} and metabolites {'NAD+', 'C00076', 'C00003', 'Calcium', 'cation'}
# Pathway path:mmu05132 involves genes {'mmu:14433'} and metabolites {'C00022', 'H2O', 'ATP', 'peroxide', 'C00001', 'Pyruvate', 'C00338', 'Hydrogen', 'Lipopolysaccharide', 'C00027', 'C00002'}
# Pathway path:mmu00620 involves genes {'mmu:58810'} and metabolites {'C00022', 'H2O', 'C00029', 'UDP-glucose', 'C00001', 'Pyruvate'}
# Pathway path:mmu00053 involves genes {'mmu:58810'} and metabolites {'C00022', 'H2O', 'C00029', 'UDP-glucose', 'C00001', 'Pyruvate'}
# Pathway path:mmu00040 involves genes {'mmu:58810'} and metabolites {'C00022', 'H2O', 'C00029', 'UDP-glucose', 'C00001', 'Pyruvate'}
# Pathway path:mmu01240 involves genes {'mmu:58810'} and metabolites {'C00022', 'H2O', 'C00029', 'UDP-glucose', 'C00001', 'Pyruvate'}
# Pathway path:mmu00561 involves genes {'mmu:58810'} and metabolites {'C00022', 'H2O', 'C00029', 'UDP-glucose', 'C00001', 'Pyruvate'}
# Pathway path:mmu00330 involves genes {'mmu:66054', 'mmu:18263'} and metabolites {'ATP', 'Peptide', 'C00012', 'Acetyl-CoA', 'C00025', 'C00005', 'NADPH', 'L-Glutamate', 'C00024', 'C00002'}
# Pathway path:mmu00340 involves genes {'mmu:66054'} and metabolites {'Peptide', 'C00012', 'L-Glutamate', 'C00024', 'Acetyl-CoA', 'C00025'}
# Pathway path:mmu00410 involves genes {'mmu:66054'} and metabolites {'Peptide', 'C00012', 'L-Glutamate', 'C00024', 'Acetyl-CoA', 'C00025'}
# Pathway path:mmu04148 involves genes {'mmu:18263'} and metabolites {'NADPH', 'ATP', 'C00012', 'Peptide', 'C00002', 'C00005'}
# Pathway path:mmu04141 involves genes {'mmu:15481'} and metabolites {'C05981', 'peroxide', 'C00035', 'Calcium', "3',5'-Cyclic", 'C00575', 'cation', 'AMP', 'C00338', 'Hydrogen', 'Phosphatidylinositol-3,4,5-trisphosphate', 'C00076', 'Lipopolysaccharide', 'GDP', 'C00027'}
# Pathway path:mmu04213 involves genes {'mmu:15481'} and metabolites {'C05981', 'peroxide', 'C00035', 'Calcium', "3',5'-Cyclic", 'C00575', 'cation', 'AMP', 'C00338', 'Hydrogen', 'Phosphatidylinositol-3,4,5-trisphosphate', 'C00076', 'Lipopolysaccharide', 'GDP', 'C00027'}
# Pathway path:mmu05145 involves genes {'mmu:15481'} and metabolites {'C05981', 'peroxide', 'C00035', 'Calcium', "3',5'-Cyclic", 'C00575', 'cation', 'AMP', 'C00338', 'Hydrogen', 'Phosphatidylinositol-3,4,5-trisphosphate', 'C00076', 'Lipopolysaccharide', 'GDP', 'C00027'}
# Pathway path:mmu04010 involves genes {'mmu:15481'} and metabolites {'C05981', 'peroxide', 'C00035', 'Calcium', "3',5'-Cyclic", 'C00575', 'cation', 'AMP', 'C00338', 'Hydrogen', 'Phosphatidylinositol-3,4,5-trisphosphate', 'C00076', 'Lipopolysaccharide', 'GDP', 'C00027'}
# Pathway path:mmu05162 involves genes {'mmu:15481'} and metabolites {'C05981', 'peroxide', 'C00035', 'Calcium', "3',5'-Cyclic", 'C00575', 'cation', 'AMP', 'C00338', 'Hydrogen', 'Phosphatidylinositol-3,4,5-trisphosphate', 'C00076', 'Lipopolysaccharide', 'GDP', 'C00027'}
# Pathway path:mmu04915 involves genes {'mmu:15481'} and metabolites {'C05981', 'peroxide', 'C00035', 'Calcium', "3',5'-Cyclic", 'C00575', 'cation', 'AMP', 'C00338', 'Hydrogen', 'Phosphatidylinositol-3,4,5-trisphosphate', 'C00076', 'Lipopolysaccharide', 'GDP', 'C00027'}
# Pathway path:mmu04144 involves genes {'mmu:15481'} and metabolites {'C05981', 'peroxide', 'C00035', 'Calcium', "3',5'-Cyclic", 'C00575', 'cation', 'AMP', 'C00338', 'Hydrogen', 'Phosphatidylinositol-3,4,5-trisphosphate', 'C00076', 'Lipopolysaccharide', 'GDP', 'C00027'}
# Pathway path:mmu05417 involves genes {'mmu:15481'} and metabolites {'C05981', 'peroxide', 'C00035', 'Calcium', "3',5'-Cyclic", 'C00575', 'cation', 'AMP', 'C00338', 'Hydrogen', 'Phosphatidylinositol-3,4,5-trisphosphate', 'C00076', 'Lipopolysaccharide', 'GDP', 'C00027'}
# Pathway path:mmu04612 involves genes {'mmu:15481'} and metabolites {'C05981', 'peroxide', 'C00035', 'Calcium', "3',5'-Cyclic", 'C00575', 'cation', 'AMP', 'C00338', 'Hydrogen', 'Phosphatidylinositol-3,4,5-trisphosphate', 'C00076', 'Lipopolysaccharide', 'GDP', 'C00027'}
# Pathway path:mmu03040 involves genes {'mmu:15481'} and metabolites {'C05981', 'peroxide', 'C00035', 'Calcium', "3',5'-Cyclic", 'C00575', 'cation', 'AMP', 'C00338', 'Hydrogen', 'Phosphatidylinositol-3,4,5-trisphosphate', 'C00076', 'Lipopolysaccharide', 'GDP', 'C00027'}
# Pathway path:mmu05205 involves genes {'mmu:21859'} and metabolites {'C00426', 'Dermatan', 'sulfate'}
# Pathway path:mmu05206 involves genes {'mmu:21859'} and metabolites {'C00426', 'Dermatan', 'sulfate'}
